# %% [markdown]
# # AGM | Unlocking AGM's Vision: The Role of NoSQL Technologies
#
# #### Notebook Contents
# * **(1) General Setup** - Library Imports and Supporting Code and Functions
# * **(2) Prepping Data**
# * **(3) SQL Analysis**
# * **(4) Neo4j Model Setup**

# %% [markdown]
# ### 1.1 Library Imports

# %%
import neo4j

import csv

import math
import numpy as np
import pandas as pd

import psycopg2

from geographiclib.geodesic import Geodesic

# %% [markdown]
# ### 1.2 Supporting code and functions for analysis

# %%
#
# function to run a select query and return rows in a pandas dataframe
# pandas puts all numeric values from postgres to float
# if it will fit in an integer, change it to integer
#

def my_select_query_pandas(query, rollback_before_flag, rollback_after_flag):
    "function to run a select query and return rows in a pandas dataframe"
    
    if rollback_before_flag:
        connection.rollback()
    
    df = pd.read_sql_query(query, connection)
    
    if rollback_after_flag:
        connection.rollback()
    
    # fix the float columns that really should be integers
    
    for column in df:
    
        if df[column].dtype == "float64":

            fraction_flag = False

            for value in df[column].values:
                
                if not np.isnan(value):
                    if value - math.floor(value) != 0:
                        fraction_flag = True

            if not fraction_flag:
                df[column] = df[column].astype('Int64')
    
    return(df)

# %%
def my_read_csv_file(file_name, limit):
    "read the csv file and print only the first limit rows"
    
    csv_file = open(file_name, "r")
    
    csv_data = csv.reader(csv_file)
    
    i = 0
    
    for row in csv_data:
        i += 1
        if i <= limit:
            print(row)
            
    print("\nPrinted ", min(limit, i), "lines of ", i, "total lines.")

# %%
driver = neo4j.GraphDatabase.driver(uri="neo4j://neo4j:7687", auth=("neo4j","ucb_mids_w205"))

# %%
session = driver.session(database="neo4j")

# %%
def my_neo4j_wipe_out_database():
    "wipe out database by deleting all nodes and relationships"
    
    query = "match (node)-[relationship]->() delete node, relationship"
    session.run(query)
    
    query = "match (node) delete node"
    session.run(query)

# %%
def my_neo4j_run_query_pandas(query, **kwargs):
    "run a query and return the results in a pandas dataframe"
    
    result = session.run(query, **kwargs)
    
    df = pd.DataFrame([r.values() for r in result], columns=result.keys())
    
    return df

# %%
def my_neo4j_number_nodes_relationships():
    "print the number of nodes and relationships"
   
    
    query = """
        match (n) 
        return n.name as node_name, labels(n) as labels
        order by n.name
    """
    
    df = my_neo4j_run_query_pandas(query)
    
    number_nodes = df.shape[0]
    
    
    query = """
        match (n1)-[r]->(n2) 
        return n1.name as node_name_1, labels(n1) as node_1_labels, 
            type(r) as relationship_type, n2.name as node_name_2, labels(n2) as node_2_labels
        order by node_name_1, node_name_2
    """
    
    df = my_neo4j_run_query_pandas(query)
    
    number_relationships = df.shape[0]
    
    print("-------------------------")
    print("  Nodes:", number_nodes)
    print("  Relationships:", number_relationships)
    print("-------------------------")

# %%
def my_neo4j_create_node(station_name):
    "create a node with label Station"
    
    query = """
    
    CREATE (:Station {name: $station_name})
    
    """
    
    session.run(query, station_name=station_name)

# %%
def my_neo4j_create_relationship_one_way(from_station, to_station, weight):
    "create a relationship one way between two stations with a weight"
    
    query = """
    
    MATCH (from:Station), 
          (to:Station)
    WHERE from.name = $from_station and to.name = $to_station
    CREATE (from)-[:LINK {weight: $weight}]->(to)
    
    """
    
    session.run(query, from_station=from_station, to_station=to_station, weight=weight)

# %%
def my_neo4j_create_relationship_two_way(from_station, to_station, weight):
    "create relationships two way between two stations with a weight"
    
    query = """
    
    MATCH (from:Station), 
          (to:Station)
    WHERE from.name = $from_station and to.name = $to_station
    CREATE (from)-[:LINK {weight: $weight}]->(to),
           (to)-[:LINK {weight: $weight}]->(from)
    
    """
    
    session.run(query, from_station=from_station, to_station=to_station, weight=weight)

# %%
def my_neo4j_shortest_path(from_station, to_station):
    "given a from station and to station, run and print the shortest path"
    
    query = "CALL gds.graph.drop('ds_graph', false)"
    session.run(query)

    query = "CALL gds.graph.project('ds_graph', 'Station', 'LINK', {relationshipProperties: 'weight'})"
    session.run(query)

    query = """

    MATCH (source:Station {name: $source}), (target:Station {name: $target})
    CALL gds.shortestPath.dijkstra.stream(
        'ds_graph', 
        { sourceNode: source, 
          targetNode: target, 
          relationshipWeightProperty: 'weight'
        }
    )
    YIELD index, sourceNode, targetNode, totalCost, nodeIds, costs, path
    RETURN
        gds.util.asNode(sourceNode).name AS from,
        gds.util.asNode(targetNode).name AS to,
        totalCost,
        [nodeId IN nodeIds | gds.util.asNode(nodeId).name] AS nodes,
        costs
    ORDER BY index

    """

    result = session.run(query, source=from_station, target=to_station)
    
    for r in result:
        
        total_cost = int(r['totalCost'])
        
        print("\n--------------------------------")
        print("   Total Cost (Seconds): ", total_cost)
        print("   Minutes: ", round(total_cost / 60.0,1))
        print("--------------------------------")
        
        nodes = r['nodes']
        costs = r['costs']
        
        i = 0
        previous = 0
        
        for n in nodes:
            
            print(n + ", " + str(int(costs[i]) - previous)  + ", " + str(int(costs[i])))
            
            previous = int(costs[i])
            i += 1

# %%
def my_calculate_box(point, miles):
    "Given a point and miles, calculate the box in form left, right, top, bottom"
    
    geod = Geodesic.WGS84

    kilometers = miles * 1.60934
    meters = kilometers * 1000

    g = geod.Direct(point[0], point[1], 270, meters)
    left = (g['lat2'], g['lon2'])

    g = geod.Direct(point[0], point[1], 90, meters)
    right = (g['lat2'], g['lon2'])

    g = geod.Direct(point[0], point[1], 0, meters)
    top = (g['lat2'], g['lon2'])

    g = geod.Direct(point[0], point[1], 180, meters)
    bottom = (g['lat2'], g['lon2'])
    
    return(left, right, top, bottom)

# %%
def my_station_get_zips(station, miles):
    "given a station, pull all zip codes with miles distance, print them, sum the population"
    
    connection.rollback()
    
    query = "select latitude, longitude from stations "
    query += "where station = '" + station + "'"
    
    cursor.execute(query)
    
    connection.rollback()
    
    rows = cursor.fetchall()
    
    for row in rows:
        latitude = row[0]
        longitude = row[1]
        
    point = (latitude, longitude)
        
    (left, right, top, bottom) = my_calculate_box(point, miles)
    
    query = "select zip, population from zip_codes "
    query += " where latitude >= " + str(bottom[0])
    query += " and latitude <= " + str(top [0])
    query += " and longitude >= " + str(left[1])
    query += " and longitude <= " + str(right[1])
    query += " order by 1 "

    cursor.execute(query)
    
    connection.rollback()
    
    rows = cursor.fetchall()
    
    print("\n-------------------------------------------------------------------------------")
    print("  Zip Codes within " + str(miles) + " mile(s) of " + station + " BART Station")
    print("-------------------------------------------------------------------------------\n")
    
    total_population = 0
    
    for row in rows:
        zip = row[0]
        population = row[1]
        print("     zip:", zip, "  population: ", f'{population:10,}')
        total_population += population
        
    
    print("\n-------------------------------------------------------------------------------")
    print("  Total Population: ", f'{total_population:10,}')
    print("-------------------------------------------------------------------------------")

# %%
def my_station_get_zips_alternative(station, miles):
    "given a station, pull all zip codes with miles distance, print them, sum the population"
    
    connection.rollback()
    
    query = "select latitude, longitude from stations "
    query += "where station = '" + station + "'"
    
    cursor.execute(query)
    
    connection.rollback()
    
    rows = cursor.fetchall()
    
    for row in rows:
        latitude = row[0]
        longitude = row[1]
        
    point = (latitude, longitude)
        
    (left, right, top, bottom) = my_calculate_box(point, miles)
    
    query = "select zip, population from zip_codes "
    query += " where latitude >= " + str(bottom[0])
    query += " and latitude <= " + str(top [0])
    query += " and longitude >= " + str(left[1])
    query += " and longitude <= " + str(right[1])
    query += " order by 1 "

    cursor.execute(query)
    
    connection.rollback()
    
    rows = cursor.fetchall()
    
    total_population = 0
    
    zip_list = []
    
    for row in rows:
        zip = row[0]
        zip_list.append(zip)
        population = row[1]
        total_population += population
    
    return {str(station): zip_list}

# %%
def my_station_get_population(station, miles):
    "given a station, get population with x amount of miles"
    
    connection.rollback()
    
    query = "select latitude, longitude from stations "
    query += "where station = '" + station + "'"
    
    cursor.execute(query)
    
    connection.rollback()
    
    rows = cursor.fetchall()
    
    for row in rows:
        latitude = row[0]
        longitude = row[1]
        
    point = (latitude, longitude)
        
    (left, right, top, bottom) = my_calculate_box(point, miles)
    
    query = "select zip, population from zip_codes "
    query += " where latitude >= " + str(bottom[0])
    query += " and latitude <= " + str(top [0])
    query += " and longitude >= " + str(left[1])
    query += " and longitude <= " + str(right[1])
    query += " order by 1 "

    cursor.execute(query)
    
    connection.rollback()
    
    rows = cursor.fetchall()
    
    total_population = 0
    
    for row in rows:
        zip = row[0]
        population = row[1]
        total_population += population
        
    
    return {str(station): int(total_population)}

# %%
connection = psycopg2.connect(
    user = "postgres",
    password = "ucb",
    host = "postgres",
    port = "5432",
    database = "postgres"
)

# %%
cursor = connection.cursor()

# %% [markdown]
# ### 2.1 Prepping Data: Drop tables if exisits

# %%
connection.rollback()

query = """

drop table if exists stations;

"""

cursor.execute(query)

connection.commit()

# %%
connection.rollback()

query = """

drop table if exists lines;

"""

cursor.execute(query)

connection.commit()

# %%
connection.rollback()

query = """

drop table if exists travel_times;

"""

cursor.execute(query)

connection.commit()

# %%
connection.rollback()

query = """

drop table if exists peak_customers

"""

cursor.execute(query)

connection.commit()

# %% [markdown]
# ### 2.2 Prepping Data: Create tables

# %%
connection.rollback()

query = """

create table stations (
  station varchar(32),
  latitude numeric(9,6),
  longitude numeric(9,6),
  transfer_time numeric(3),
  primary key (station));

"""

cursor.execute(query)

connection.commit()

# %%
connection.rollback()

query = """

create table lines (
    line varchar(6),
    sequence numeric(2),
    station varchar(32),
    primary key (line, sequence));
"""

cursor.execute(query)

connection.commit()

# %%
connection.rollback()

query = """

create table travel_times (
  station_1 varchar(32),
  station_2 varchar(32),
  travel_time numeric(3),
  primary key (station_1, station_2)
);
"""

cursor.execute(query)

connection.commit()

# %%
connection.rollback()

query = """

create table peak_customers (
  customer_id varchar(100),
  first_name varchar(100),
  last_name varchar(100),
  street varchar(100),
  city varchar(100),
  state varchar(100),
  zip varchar(100),
  closest_store_id varchar(100),
  distance varchar(100)
  
)
"""

cursor.execute(query)

connection.commit()

# %% [markdown]
# ### 2.3 Prepping Data: Load data into database from csv files

# %%
connection.rollback()

query = """

COPY stations
from '/user/projects/project-3-Tyler-Gustafson/exercise/stations.csv' delimiter ',' NULL '' csv header;

"""

cursor.execute(query)

connection.commit()

# %%
connection.rollback()

query = """

copy lines
from '/user/projects/project-3-Tyler-Gustafson/exercise/lines.csv' delimiter ',' NULL '' csv header;

"""

cursor.execute(query)

connection.commit()

# %%
connection.rollback()

query = """

copy travel_times
from '/user/projects/project-3-Tyler-Gustafson/exercise/travel_times.csv' delimiter ',' NULL '' csv header;
"""

cursor.execute(query)

connection.commit()

# %%
connection.rollback()

query = """

copy peak_customers
from '/user/projects/project-3-Tyler-Gustafson/code/berkeley_customers_data.csv' delimiter ',' NULL '' csv header;
"""

cursor.execute(query)

connection.commit()

# %% [markdown]
# ## 3.1 SQL Analysis - customers and routes

# %%
# Query the list of stations
rollback_before_flag = True
rollback_after_flag = True

query = """

SELECT *
FROM peak_customers
"""

my_select_query_pandas(query, rollback_before_flag, rollback_after_flag)
# Out:
#      customer_id first_name     last_name                   street      city  \
# 0           3449     Whitby    Mennithorp           3158 2nd Point   Alameda
# 1           3617    Justino       Tenaunt    7635 Caliangt Terrace   Alameda
# 2           3616       Chev        Devers  22857 Golf View Terrace   Alameda
# 3           3615         Ki       Scrange        326 Utah Junction   Alameda
# 4           3614    Letizia       Munkley            2 Calypso Way   Alameda
# ...          ...        ...           ...                      ...       ...
# 8133        8095      Emmet       Phippin   78379 Fieldstone Trail  Woodacre
# 8134        8096      Ulric  Ravenscroftt          36849 Eagan Way  Woodacre
# 8135        8097     Jeremy        Diable        942 Rigney Circle  Woodacre
# 8136        8098      Luisa       Symcoxe      291 Thompson Street  Woodacre
# 8137        8099     Adella       Buscher      20 Scofield Parkway  Woodacre
#
#      state    zip closest_store_id distance
# 0       CA  94501                1        6
# 1       CA  94501                1        6
# 2       CA  94501                1        6
# 3       CA  94501                1        6
# 4       CA  94501                1        6
# ...    ...    ...              ...      ...
# 8133    CA  94973                1       23
# 8134    CA  94973                1       23
# 8135    CA  94973                1       23
# 8136    CA  94973                1       23
# 8137    CA  94973                1       23
#
# [8138 rows x 9 columns]

# %%
# Query the list of stations
rollback_before_flag = True
rollback_after_flag = True

query = """

SELECT station
FROM stations
ORDER BY station
"""

stations = my_select_query_pandas(query, rollback_before_flag, rollback_after_flag)['station'].tolist()

# %%
all_stations_zip_dictionary = {}

for station in stations:
    result = my_station_get_zips_alternative(station, 7)
    all_stations_zip_dictionary.update(result)
    
all_stations_zip_dictionary
# Out:
# {'12th Street': ['94105',
#   '94107',
#   '94111',
#   '94124',
#   '94130',
#   '94158',
#   '94501',
#   '94502',
#   '94516',
#   '94563',
#   '94577',
#   '94601',
#   '94602',
#   '94603',
#   '94605',
#   '94606',
#   '94607',
#   '94608',
#   '94609',
#   '94610',
#   '94611',
#   '94612',
#   '94613',
#   '94618',
#   '94621',
#   '94702',
#   '94703',
#   '94704',
#   '94705',
#   '94706',
#   '94707',
#   '94708',
#   '94709',
#   '94710',
#   '94720'],
#  '16th Street Mission': ['94005',
#   '94014',
#   '94015',
#   '94102',
#   '94103',
#   '94104',
#   '94105',
#   '94107',
#   '94108',
#   '94109',
#   '94110',
#   '94111',
#   '94112',
#   '94114',
#   '94115',
#   '94116',
#   '94117',
#   '94118',
#   '94121',
#   '94122',
#   '94123',
#   '94124',
#   '94127',
#   '94129',
#   '94130',
#   '94131',
#   '94132',
#   '94133',
#   '94134',
#   '94158',
#   '94607',
#   '94965'],
#  '19th Street': ['94105',
#   '94107',
#   '94124',
#   '94130',
#   '94158',
#   '94501',
#   '94502',
#   '94516',
#   '94563',
#   '94577',
#   '94601',
#   '94602',
#   '94603',
#   '94605',
#   '94606',
#   '94607',
#   '94608',
#   '94609',
#   '94610',
#   '94611',
#   '94612',
#   '94613',
#   '94618',
#   '94621',
#   '94702',
#   '94703',
#   '94704',
#   '94705',
#   '94706',
#   '94707',
#   '94708',
#   '94709',
#   '94710',
#   '94720'],
#  '24th Street Mission': ['94005',
#   '94014',
#   '94015',
#   '94080',
#   '94102',
#   '94103',
#   '94104',
#   '94105',
#   '94107',
#   '94108',
#   '94109',
#   '94110',
#   '94111',
#   '94112',
#   '94114',
#   '94115',
#   '94116',
#   '94117',
#   '94118',
#   '94121',
#   '94122',
#   '94123',
#   '94124',
#   '94127',
#   '94129',
#   '94130',
#   '94131',
#   '94132',
#   '94133',
#   '94134',
#   '94158',
#   '94607',
#   '94965'],
#  'Antioch': ['94509', '94513', '94531', '94561', '94565'],
#  'Ashby': ['94105',
#   '94107',
#   '94130',
#   '94158',
#   '94501',
#   '94516',
#   '94530',
#   '94563',
#   '94601',
#   '94602',
#   '94605',
#   '94606',
#   '94607',
#   '94608',
#   '94609',
#   '94610',
#   '94611',
#   '94612',
#   '94613',
#   '94618',
#   '94702',
#   '94703',
#   '94704',
#   '94705',
#   '94706',
#   '94707',
#   '94708',
#   '94709',
#   '94710',
#   '94720',
#   '94801',
#   '94804',
#   '94805'],
#  'Balboa Park': ['94005',
#   '94014',
#   '94015',
#   '94066',
#   '94080',
#   '94102',
#   '94103',
#   '94104',
#   '94105',
#   '94107',
#   '94108',
#   '94109',
#   '94110',
#   '94111',
#   '94112',
#   '94114',
#   '94115',
#   '94116',
#   '94117',
#   '94118',
#   '94121',
#   '94122',
#   '94123',
#   '94124',
#   '94127',
#   '94128',
#   '94129',
#   '94130',
#   '94131',
#   '94132',
#   '94133',
#   '94134',
#   '94158'],
#  'Bay Fair': ['94502',
#   '94541',
#   '94542',
#   '94544',
#   '94545',
#   '94546',
#   '94552',
#   '94577',
#   '94578',
#   '94579',
#   '94580',
#   '94587',
#   '94601',
#   '94603',
#   '94605',
#   '94606',
#   '94613',
#   '94619',
#   '94621'],
#  'Berryessa': ['95008',
#   '95035',
#   '95050',
#   '95051',
#   '95053',
#   '95054',
#   '95110',
#   '95111',
#   '95112',
#   '95113',
#   '95116',
#   '95117',
#   '95121',
#   '95122',
#   '95125',
#   '95126',
#   '95127',
#   '95128',
#   '95129',
#   '95130',
#   '95131',
#   '95132',
#   '95133',
#   '95134',
#   '95136',
#   '95148'],
#  'Castro Valley': ['94541',
#   '94542',
#   '94544',
#   '94545',
#   '94546',
#   '94552',
#   '94577',
#   '94578',
#   '94579',
#   '94580',
#   '94583',
#   '94587',
#   '94603',
#   '94605',
#   '94613',
#   '94619'],
#  'Civic Center': ['94005',
#   '94014',
#   '94015',
#   '94102',
#   '94103',
#   '94104',
#   '94105',
#   '94107',
#   '94108',
#   '94109',
#   '94110',
#   '94111',
#   '94112',
#   '94114',
#   '94115',
#   '94116',
#   '94117',
#   '94118',
#   '94121',
#   '94122',
#   '94123',
#   '94124',
#   '94127',
#   '94129',
#   '94130',
#   '94131',
#   '94132',
#   '94133',
#   '94134',
#   '94158',
#   '94607',
#   '94608',
#   '94702',
#   '94710',
#   '94965'],
#  'Coliseum': ['94501',
#   '94502',
#   '94516',
#   '94541',
#   '94546',
#   '94556',
#   '94575',
#   '94577',
#   '94578',
#   '94579',
#   '94580',
#   '94601',
#   '94602',
#   '94603',
#   '94605',
#   '94606',
#   '94607',
#   '94608',
#   '94609',
#   '94610',
#   '94611',
#   '94612',
#   '94613',
#   '94618',
#   '94619',
#   '94621'],
#  'Colma': ['94005',
#   '94014',
#   '94015',
#   '94030',
#   '94044',
#   '94066',
#   '94080',
#   '94102',
#   '94103',
#   '94107',
#   '94110',
#   '94112',
#   '94114',
#   '94115',
#   '94116',
#   '94117',
#   '94118',
#   '94121',
#   '94122',
#   '94124',
#   '94127',
#   '94128',
#   '94131',
#   '94132',
#   '94134',
#   '94158'],
#  'Concord': ['94518',
#   '94519',
#   '94520',
#   '94521',
#   '94523',
#   '94549',
#   '94553',
#   '94565',
#   '94596',
#   '94597',
#   '94598'],
#  'Daly City': ['94005',
#   '94014',
#   '94015',
#   '94044',
#   '94066',
#   '94080',
#   '94102',
#   '94103',
#   '94104',
#   '94105',
#   '94107',
#   '94108',
#   '94109',
#   '94110',
#   '94111',
#   '94112',
#   '94114',
#   '94115',
#   '94116',
#   '94117',
#   '94118',
#   '94121',
#   '94122',
#   '94123',
#   '94124',
#   '94127',
#   '94128',
#   '94129',
#   '94131',
#   '94132',
#   '94133',
#   '94134',
#   '94158'],
#  'Downtown Berkeley': ['94105',
#   '94130',
#   '94158',
#   '94501',
#   '94516',
#   '94530',
#   '94563',
#   '94601',
#   '94602',
#   '94606',
#   '94607',
#   '94608',
#   '94609',
#   '94610',
#   '94611',
#   '94612',
#   '94613',
#   '94618',
#   '94702',
#   '94703',
#   '94704',
#   '94705',
#   '94706',
#   '94707',
#   '94708',
#   '94709',
#   '94710',
#   '94720',
#   '94801',
#   '94803',
#   '94804',
#   '94805'],
#  'Dublin': ['94552', '94566', '94568', '94582', '94583', '94587', '94588'],
#  'El Cerrito del Norte': ['94530',
#   '94547',
#   '94564',
#   '94608',
#   '94609',
#   '94611',
#   '94618',
#   '94702',
#   '94703',
#   '94704',
#   '94705',
#   '94706',
#   '94707',
#   '94708',
#   '94709',
#   '94710',
#   '94720',
#   '94801',
#   '94803',
#   '94804',
#   '94805',
#   '94806'],
#  'El Cerrito Plaza': ['94130',
#   '94133',
#   '94530',
#   '94563',
#   '94564',
#   '94602',
#   '94607',
#   '94608',
#   '94609',
#   '94610',
#   '94611',
#   '94612',
#   '94618',
#   '94702',
#   '94703',
#   '94704',
#   '94705',
#   '94706',
#   '94707',
#   '94708',
#   '94709',
#   '94710',
#   '94720',
#   '94801',
#   '94803',
#   '94804',
#   '94805',
#   '94806'],
#  'Embarcadero': ['94102',
#   '94103',
#   '94104',
#   '94105',
#   '94107',
#   '94108',
#   '94109',
#   '94110',
#   '94111',
#   '94112',
#   '94114',
#   '94115',
#   '94116',
#   '94117',
#   '94118',
#   '94121',
#   '94122',
#   '94123',
#   '94124',
#   '94127',
#   '94129',
#   '94130',
#   '94131',
#   '94132',
#   '94133',
#   '94134',
#   '94158',
#   '94501',
#   '94607',
#   '94608',
#   '94702',
#   '94703',
#   '94706',
#   '94710',
#   '94920',
#   '94965'],
#  'Fremont': ['94536',
#   '94538',
#   '94539',
#   '94544',
#   '94555',
#   '94560',
#   '94566',
#   '94586',
#   '94587'],
#  'Fruitvale': ['94501',
#   '94502',
#   '94516',
#   '94556',
#   '94575',
#   '94577',
#   '94578',
#   '94579',
#   '94580',
#   '94601',
#   '94602',
#   '94603',
#   '94605',
#   '94606',
#   '94607',
#   '94608',
#   '94609',
#   '94610',
#   '94611',
#   '94612',
#   '94613',
#   '94618',
#   '94619',
#   '94621',
#   '94702',
#   '94703',
#   '94704',
#   '94705',
#   '94710',
#   '94720'],
#  'Glen Park': ['94005',
#   '94014',
#   '94015',
#   '94080',
#   '94102',
#   '94103',
#   '94104',
#   '94105',
#   '94107',
#   '94108',
#   '94109',
#   '94110',
#   '94111',
#   '94112',
#   '94114',
#   '94115',
#   '94116',
#   '94117',
#   '94118',
#   '94121',
#   '94122',
#   '94123',
#   '94124',
#   '94127',
#   '94129',
#   '94130',
#   '94131',
#   '94132',
#   '94133',
#   '94134',
#   '94158'],
#  'Hayward': ['94536',
#   '94541',
#   '94542',
#   '94544',
#   '94545',
#   '94546',
#   '94552',
#   '94577',
#   '94578',
#   '94579',
#   '94580',
#   '94583',
#   '94587',
#   '94603',
#   '94605',
#   '94621'],
#  'Lafayette': ['94507',
#   '94516',
#   '94518',
#   '94519',
#   '94523',
#   '94549',
#   '94556',
#   '94563',
#   '94575',
#   '94595',
#   '94596',
#   '94597',
#   '94598',
#   '94602',
#   '94606',
#   '94610',
#   '94611',
#   '94618',
#   '94705'],
#  'Lake Merritt': ['94105',
#   '94124',
#   '94130',
#   '94158',
#   '94501',
#   '94502',
#   '94516',
#   '94563',
#   '94577',
#   '94601',
#   '94602',
#   '94603',
#   '94605',
#   '94606',
#   '94607',
#   '94608',
#   '94609',
#   '94610',
#   '94611',
#   '94612',
#   '94613',
#   '94618',
#   '94621',
#   '94702',
#   '94703',
#   '94704',
#   '94705',
#   '94706',
#   '94707',
#   '94709',
#   '94710',
#   '94720'],
#  'MacArthur': ['94105',
#   '94107',
#   '94124',
#   '94130',
#   '94158',
#   '94501',
#   '94502',
#   '94516',
#   '94530',
#   '94563',
#   '94601',
#   '94602',
#   '94603',
#   '94605',
#   '94606',
#   '94607',
#   '94608',
#   '94609',
#   '94610',
#   '94611',
#   '94612',
#   '94613',
#   '94618',
#   '94621',
#   '94702',
#   '94703',
#   '94704',
#   '94705',
#   '94706',
#   '94707',
#   '94708',
#   '94709',
#   '94710',
#   '94720',
#   '94804'],
#  'Millbrae': ['94002',
#   '94005',
#   '94010',
#   '94014',
#   '94015',
#   '94030',
#   '94037',
#   '94038',
#   '94044',
#   '94066',
#   '94080',
#   '94128',
#   '94401',
#   '94402',
#   '94403',
#   '94404'],
#  'Milpitas': ['94085',
#   '94089',
#   '94538',
#   '95002',
#   '95035',
#   '95050',
#   '95051',
#   '95053',
#   '95054',
#   '95110',
#   '95112',
#   '95113',
#   '95116',
#   '95117',
#   '95122',
#   '95126',
#   '95127',
#   '95128',
#   '95131',
#   '95132',
#   '95133',
#   '95134',
#   '95148'],
#  'Montgomery Street': ['94005',
#   '94014',
#   '94102',
#   '94103',
#   '94104',
#   '94105',
#   '94107',
#   '94108',
#   '94109',
#   '94110',
#   '94111',
#   '94112',
#   '94114',
#   '94115',
#   '94116',
#   '94117',
#   '94118',
#   '94121',
#   '94122',
#   '94123',
#   '94124',
#   '94127',
#   '94129',
#   '94130',
#   '94131',
#   '94132',
#   '94133',
#   '94134',
#   '94158',
#   '94501',
#   '94607',
#   '94608',
#   '94702',
#   '94703',
#   '94706',
#   '94710',
#   '94920',
#   '94965'],
#  'North Berkeley': ['94104',
#   '94105',
#   '94108',
#   '94111',
#   '94130',
#   '94501',
#   '94516',
#   '94530',
#   '94563',
#   '94601',
#   '94602',
#   '94606',
#   '94607',
#   '94608',
#   '94609',
#   '94610',
#   '94611',
#   '94612',
#   '94613',
#   '94618',
#   '94702',
#   '94703',
#   '94704',
#   '94705',
#   '94706',
#   '94707',
#   '94708',
#   '94709',
#   '94710',
#   '94720',
#   '94801',
#   '94803',
#   '94804',
#   '94805'],
#  'North Concord': ['94510',
#   '94518',
#   '94519',
#   '94520',
#   '94521',
#   '94523',
#   '94553',
#   '94565',
#   '94597'],
#  'OAK': ['94501',
#   '94502',
#   '94541',
#   '94545',
#   '94577',
#   '94578',
#   '94579',
#   '94580',
#   '94601',
#   '94602',
#   '94603',
#   '94605',
#   '94606',
#   '94607',
#   '94610',
#   '94612',
#   '94613',
#   '94619',
#   '94621'],
#  'Orinda': ['94516',
#   '94523',
#   '94530',
#   '94549',
#   '94556',
#   '94563',
#   '94575',
#   '94595',
#   '94597',
#   '94602',
#   '94606',
#   '94607',
#   '94608',
#   '94609',
#   '94610',
#   '94611',
#   '94612',
#   '94613',
#   '94618',
#   '94619',
#   '94702',
#   '94703',
#   '94704',
#   '94705',
#   '94706',
#   '94707',
#   '94708',
#   '94709',
#   '94710',
#   '94720',
#   '94803'],
#  'Pittsburg': ['94518', '94519', '94520', '94521', '94565', '94597'],
#  'Pittsburg Center': ['94509', '94519', '94521', '94531', '94565'],
#  'Pleasant Hill': ['94507',
#   '94516',
#   '94518',
#   '94519',
#   '94520',
#   '94521',
#   '94523',
#   '94528',
#   '94549',
#   '94553',
#   '94556',
#   '94575',
#   '94595',
#   '94596',
#   '94597',
#   '94598'],
#  'Powell Street': ['94005',
#   '94014',
#   '94102',
#   '94103',
#   '94104',
#   '94105',
#   '94107',
#   '94108',
#   '94109',
#   '94110',
#   '94111',
#   '94112',
#   '94114',
#   '94115',
#   '94116',
#   '94117',
#   '94118',
#   '94121',
#   '94122',
#   '94123',
#   '94124',
#   '94127',
#   '94129',
#   '94130',
#   '94131',
#   '94132',
#   '94133',
#   '94134',
#   '94158',
#   '94607',
#   '94608',
#   '94702',
#   '94710',
#   '94965'],
#  'Richmond': ['94530',
#   '94547',
#   '94564',
#   '94572',
#   '94608',
#   '94618',
#   '94702',
#   '94703',
#   '94704',
#   '94705',
#   '94706',
#   '94707',
#   '94708',
#   '94709',
#   '94710',
#   '94720',
#   '94801',
#   '94803',
#   '94804',
#   '94805',
#   '94806',
#   '94920'],
#  'Rockridge': ['94130',
#   '94501',
#   '94516',
#   '94530',
#   '94563',
#   '94601',
#   '94602',
#   '94605',
#   '94606',
#   '94607',
#   '94608',
#   '94609',
#   '94610',
#   '94611',
#   '94612',
#   '94613',
#   '94618',
#   '94619',
#   '94702',
#   '94703',
#   '94704',
#   '94705',
#   '94706',
#   '94707',
#   '94708',
#   '94709',
#   '94710',
#   '94720',
#   '94804',
#   '94805'],
#  'San Bruno': ['94005',
#   '94010',
#   '94014',
#   '94015',
#   '94030',
#   '94037',
#   '94044',
#   '94066',
#   '94080',
#   '94112',
#   '94124',
#   '94127',
#   '94128',
#   '94132',
#   '94134',
#   '94401',
#   '94402',
#   '94403'],
#  'San Leandro': ['94501',
#   '94502',
#   '94541',
#   '94542',
#   '94544',
#   '94546',
#   '94577',
#   '94578',
#   '94579',
#   '94580',
#   '94601',
#   '94602',
#   '94603',
#   '94605',
#   '94606',
#   '94610',
#   '94612',
#   '94613',
#   '94619',
#   '94621'],
#  'SFO': ['94005',
#   '94010',
#   '94014',
#   '94015',
#   '94030',
#   '94037',
#   '94038',
#   '94044',
#   '94066',
#   '94080',
#   '94128',
#   '94401',
#   '94402',
#   '94403',
#   '94404'],
#  'South Hayward': ['94536',
#   '94541',
#   '94542',
#   '94544',
#   '94545',
#   '94546',
#   '94552',
#   '94555',
#   '94577',
#   '94578',
#   '94579',
#   '94580',
#   '94587'],
#  'South San Francisco': ['94005',
#   '94010',
#   '94014',
#   '94015',
#   '94030',
#   '94044',
#   '94066',
#   '94080',
#   '94110',
#   '94112',
#   '94114',
#   '94116',
#   '94122',
#   '94124',
#   '94127',
#   '94128',
#   '94131',
#   '94132',
#   '94134',
#   '94401'],
#  'Union City': ['94536',
#   '94538',
#   '94539',
#   '94541',
#   '94542',
#   '94544',
#   '94545',
#   '94555',
#   '94560',
#   '94580',
#   '94587'],
#  'Walnut Creek': ['94507',
#   '94516',
#   '94518',
#   '94519',
#   '94520',
#   '94521',
#   '94523',
#   '94526',
#   '94528',
#   '94549',
#   '94553',
#   '94556',
#   '94563',
#   '94575',
#   '94595',
#   '94596',
#   '94597',
#   '94598'],
#  'Warm Springs': ['94089',
#   '94536',
#   '94538',
#   '94539',
#   '94560',
#   '94586',
#   '94587',
#   '95002',
#   '95035',
#   '95134'],
#  'West Dublin': ['94542',
#   '94552',
#   '94566',
#   '94568',
#   '94582',
#   '94583',
#   '94587',
#   '94588'],
#  'West Oakland': ['94102',
#   '94103',
#   '94104',
#   '94105',
#   '94107',
#   '94108',
#   '94109',
#   '94110',
#   '94111',
#   '94124',
#   '94130',
#   '94133',
#   '94134',
#   '94158',
#   '94501',
#   '94502',
#   '94563',
#   '94601',
#   '94602',
#   '94603',
#   '94606',
#   '94607',
#   '94608',
#   '94609',
#   '94610',
#   '94611',
#   '94612',
#   '94613',
#   '94618',
#   '94621',
#   '94702',
#   '94703',
#   '94704',
#   '94705',
#   '94706',
#   '94707',
#   '94708',
#   '94709',
#   '94710',
#   '94720']}

# %%
# Assuming all_stations_zip_dictionary is your dictionary of stations and associated zip codes
data_for_df = []

for station, zip_codes in all_stations_zip_dictionary.items():
    # Convert the list of zip codes to a string format suitable for SQL IN clause
    zip_codes_str = "'" + "', '".join(zip_codes) + "'"
    
    # Construct SQL query
    query = f"""
    SELECT COUNT(*) as customer_count
    FROM peak_customers
    WHERE zip IN ({zip_codes_str})
    """
    
    # Execute the query and get the result in a DataFrame
    result_df = my_select_query_pandas(query, rollback_before_flag, rollback_after_flag)
    
    # Assuming the query returns a single row with a single column 'customer_count'
    if not result_df.empty:
        customer_count = result_df.iloc[0]['customer_count']
    else:
        customer_count = 0 
    
    # Append the station name and customer count to the data list
    data_for_df.append({'Station': station, 'Current Customer Count Within 7 Miles': customer_count})

# Create a DataFrame from the accumulated data
df_stations_customers = pd.DataFrame(data_for_df)

df_stations_customers['Percentage (%)'] = (df_stations_customers['Current Customer Count Within 7 Miles'] / 8138 * 100).round(2)

# Display the DataFrame
df_stations_customers.sort_values(by='Current Customer Count Within 7 Miles', ascending = False)
# Out:
#                  Station  Current Customer Count Within 7 Miles  \
# 49          West Oakland                                   4594
# 30        North Berkeley                                   4589
# 26             MacArthur                                   4572
# 15     Downtown Berkeley                                   4554
# 5                  Ashby                                   4458
# 39             Rockridge                                   4277
# 0            12th Street                                   4240
# 2            19th Street                                   4204
# 33                Orinda                                   4202
# 18      El Cerrito Plaza                                   4067
# 25          Lake Merritt                                   4015
# 21             Fruitvale                                   3570
# 17  El Cerrito del Norte                                   3062
# 11              Coliseum                                   2886
# 38              Richmond                                   2828
# 29     Montgomery Street                                   2816
# 19           Embarcadero                                   2734
# 10          Civic Center                                   2240
# 37         Powell Street                                   2236
# 24             Lafayette                                   1986
# 32                   OAK                                   1980
# 41           San Leandro                                   1818
# 3    24th Street Mission                                   1773
# 1    16th Street Mission                                   1764
# 6            Balboa Park                                   1541
# 22             Glen Park                                   1531
# 14             Daly City                                   1511
# 12                 Colma                                   1133
# 7               Bay Fair                                   1063
# 46          Walnut Creek                                    994
# 36         Pleasant Hill                                    761
# 44   South San Francisco                                    651
# 23               Hayward                                    510
# 9          Castro Valley                                    508
# 13               Concord                                    486
# 40             San Bruno                                    400
# 43         South Hayward                                    339
# 31         North Concord                                    273
# 27              Millbrae                                    160
# 42                   SFO                                    156
# 34             Pittsburg                                    154
# 45            Union City                                    101
# 48           West Dublin                                     44
# 16                Dublin                                     36
# 20               Fremont                                     35
# 47          Warm Springs                                     17
# 35      Pittsburg Center                                      9
# 4                Antioch                                      1
# 8              Berryessa                                      0
# 28              Milpitas                                      0
#
#     Percentage (%)
# 49           56.45
# 30           56.39
# 26           56.18
# 15           55.96
# 5            54.78
# 39           52.56
# 0            52.10
# 2            51.66
# 33           51.63
# 18           49.98
# 25           49.34
# 21           43.87
# 17           37.63
# 11           35.46
# 38           34.75
# 29           34.60
# 19           33.60
# 10           27.53
# 37           27.48
# 24           24.40
# 32           24.33
# 41           22.34
# 3            21.79
# 1            21.68
# 6            18.94
# 22           18.81
# 14           18.57
# 12           13.92
# 7            13.06
# 46           12.21
# 36            9.35
# 44            8.00
# 23            6.27
# 9             6.24
# 13            5.97
# 40            4.92
# 43            4.17
# 31            3.35
# 27            1.97
# 42            1.92
# 34            1.89
# 45            1.24
# 48            0.54
# 16            0.44
# 20            0.43
# 47            0.21
# 35            0.11
# 4             0.01
# 8             0.00
# 28            0.00

# %%
# Query the lines served by the West Oakland Station
rollback_before_flag = True
rollback_after_flag = True

query = """

SELECT station,
    line
FROM lines
WHERE station = 'West Oakland'
ORDER BY station, line
"""

my_select_query_pandas(query, rollback_before_flag, rollback_after_flag)
# Out:
#         station    line
# 0  West Oakland    blue
# 1  West Oakland   green
# 2  West Oakland     red
# 3  West Oakland  yellow

# %%
# Query of the list of stations and the lines they serve
rollback_before_flag = True
rollback_after_flag = True

query = """

SELECT station,
    line
FROM lines
ORDER BY station, line
"""

my_select_query_pandas(query, rollback_before_flag, rollback_after_flag)
# Out:
#                  station    line
# 0            12th Street  orange
# 1            12th Street     red
# 2            12th Street  yellow
# 3    16th Street Mission    blue
# 4    16th Street Mission   green
# ..                   ...     ...
# 109          West Dublin    blue
# 110         West Oakland    blue
# 111         West Oakland   green
# 112         West Oakland     red
# 113         West Oakland  yellow
#
# [114 rows x 2 columns]

# %%
# Query the list of all possible line transfers at the West Oakland station and the transfer times
rollback_before_flag = True
rollback_after_flag = True

query = """

SELECT a.station, a.line as from_line, b.line as to_line, s.transfer_time
FROM lines a
    JOIN lines b
        ON a.station = b.station AND a.line <> b.line
    JOIN stations s
        ON a.station = s.station
WHERE a.station = 'West Oakland'
ORDER BY a.station, from_line, to_line
"""

my_select_query_pandas(query, rollback_before_flag, rollback_after_flag)
# Out:
#          station from_line to_line  transfer_time
# 0   West Oakland      blue   green            283
# 1   West Oakland      blue     red            283
# 2   West Oakland      blue  yellow            283
# 3   West Oakland     green    blue            283
# 4   West Oakland     green     red            283
# 5   West Oakland     green  yellow            283
# 6   West Oakland       red    blue            283
# 7   West Oakland       red   green            283
# 8   West Oakland       red  yellow            283
# 9   West Oakland    yellow    blue            283
# 10  West Oakland    yellow   green            283
# 11  West Oakland    yellow     red            283

# %%
# Query the list of all possible line transfers and the transfer times
rollback_before_flag = True
rollback_after_flag = True

query = """

SELECT a.station, a.line AS from_line, b.line AS to_line, s.transfer_time
FROM lines a
    JOIN lines b 
        ON a.station = b.station AND a.line <> b.line
    JOIN stations s
        ON a.station = s.station
ORDER BY a.station, a.line, b.line

"""

my_select_query_pandas(query, rollback_before_flag, rollback_after_flag)
# Out:
#           station from_line to_line  transfer_time
# 0     12th Street    orange     red            282
# 1     12th Street    orange  yellow            282
# 2     12th Street       red  orange            282
# 3     12th Street       red  yellow            282
# 4     12th Street    yellow  orange            282
# ..            ...       ...     ...            ...
# 203  West Oakland       red   green            283
# 204  West Oakland       red  yellow            283
# 205  West Oakland    yellow    blue            283
# 206  West Oakland    yellow   green            283
# 207  West Oakland    yellow     red            283
#
# [208 rows x 4 columns]

# %%
# Query the list of all segments between each station and its adjoining stations
rollback_before_flag = True
rollback_after_flag = True

query = """

SELECT a.line, a.station AS from_station, b.station AS to_station, t.travel_time
FROM lines a
  JOIN lines b
    ON a.line = b.line AND b.sequence = (a.sequence + 1)
  JOIN travel_times t
    ON (a.station = t.station_1 AND b.station = t.station_2)
        OR (a.station = t.station_2 AND b.station = t.station_1)
ORDER BY line, from_station, to_station
"""

my_select_query_pandas(query, rollback_before_flag, rollback_after_flag)
# Out:
#        line         from_station           to_station  travel_time
# 0      blue  16th Street Mission  24th Street Mission          120
# 1      blue  24th Street Mission            Glen Park          180
# 2      blue          Balboa Park            Daly City          240
# 3      blue             Bay Fair          San Leandro          240
# 4      blue        Castro Valley             Bay Fair          240
# ..      ...                  ...                  ...          ...
# 103  yellow            Rockridge            MacArthur          240
# 104  yellow            San Bruno                  SFO          240
# 105  yellow  South San Francisco            San Bruno          240
# 106  yellow         Walnut Creek            Lafayette          300
# 107  yellow         West Oakland          Embarcadero          420
#
# [108 rows x 4 columns]

# %% [markdown]
# ## 4.1 Neo4j: Setting up the NoSql graph database

# %%
my_neo4j_wipe_out_database()

# %%
# Verify the number of nodes and relationships
my_neo4j_number_nodes_relationships()
# Out:
# -------------------------
#   Nodes: 0
#   Relationships: 0
# -------------------------

# %% [markdown]
# ### Only build these out if looking to use shortest path algorithm

# %%
# # Query the list of stations and create the departure and arrival nodes in the graph

# connection.rollback()

# query = """

# select station
# from stations
# order by station

# """

# cursor.execute(query)

# connection.rollback()

# rows = cursor.fetchall()

# for row in rows:
    
#     station = row[0]
    
#     my_neo4j_create_node('depart ' + station)
#     my_neo4j_create_node('arrive ' + station)

# %%
# Verify the number of nodes and relationships
my_neo4j_number_nodes_relationships()
# Out:
# -------------------------
#   Nodes: 0
#   Relationships: 0
# -------------------------

# %%
# Query the list of stations and the lines they serve, create line nodes, and create relationships between the line nodes and the departure and arrival nodes with weight 0

connection.rollback()

query = """

select station, line
from lines
order by station, line

"""

cursor.execute(query)

connection.rollback()

#Creates a list of tuples
rows = cursor.fetchall()

#iterates over each tuple
for row in rows:
    
    station = row[0]
    line = row[1]
    
    depart = 'depart ' + station
    arrive = 'arrive ' + station
    line_station = line + ' ' + station
    
    my_neo4j_create_node(line_station)
    my_neo4j_create_relationship_one_way(depart, line_station, 0)
    my_neo4j_create_relationship_one_way(line_station, arrive, 0)

# %%
my_neo4j_number_nodes_relationships()
# Out:
# -------------------------
#   Nodes: 114
#   Relationships: 0
# -------------------------

# %%
# Query the list of all possible line transfers and the transfer times, create a relationship for each transfer with the transfer time as the weight
connection.rollback()

query = """

select a.station, a.line as from_line, b.line as to_line, s.transfer_time
from lines a
     join lines b
       on a.station = b.station and a.line <> b.line 
     join stations s
       on a.station = s.station
order by 1, 2, 3

"""

cursor.execute(query)

connection.rollback()

rows = cursor.fetchall()

for row in rows:
    
    station = row[0]
    from_line = row[1]
    to_line = row[2]
    transfer_time = int(row[3])
    
    from_station = from_line + ' ' + station
    to_station = to_line + ' ' + station
    
    my_neo4j_create_relationship_one_way(from_station, to_station, transfer_time)

# %%
my_neo4j_number_nodes_relationships()
# Out:
# -------------------------
#   Nodes: 114
#   Relationships: 208
# -------------------------

# %%
# Query the list of all segments between each station and its adjoining stations, create a relationship for each segment both ways
connection.rollback()

query = """

select a.line, a.station as from_station, b.station as to_station, t.travel_time
from lines a
  join lines b
    on a.line = b.line and b.sequence = (a.sequence + 1)
  join travel_times t
    on (a.station = t.station_1 and b.station = t.station_2)
        or (a.station = t.station_2 and b.station = t.station_1)
order by line, from_station, to_station

"""

cursor.execute(query)

connection.rollback()

rows = cursor.fetchall()

for row in rows:
    
    line = row[0]
    from_station = line + ' ' + row[1]
    to_station = line + ' ' + row[2]
    travel_time = int(row[3])
    
    my_neo4j_create_relationship_two_way(from_station, to_station, travel_time)

# %%
# Verify the number of nodes and relationships
my_neo4j_number_nodes_relationships()
# Out:
# -------------------------
#   Nodes: 114
#   Relationships: 424
# -------------------------

# %% [markdown]
# ## 4.2 Neo4j: Applying NoSql Graph Algorithms

# %% [markdown]
# #### Algorithm | Shortest Path (make sure depart / arrive are in the model)

# %%
# Shortest path between Embarcadero and Civic Center
my_neo4j_shortest_path('depart Embarcadero', 'arrive Civic Center')
# Out:
# --------------------------------
#    Total Cost (Seconds):  240
#    Minutes:  4.0
# --------------------------------
# depart Embarcadero, 0, 0
# yellow Embarcadero, 0, 0
# yellow Montgomery Street, 60, 60
# yellow Powell Street, 120, 180
# yellow Civic Center, 60, 240
# arrive Civic Center, 0, 240

# %% [markdown]
# #### Algorithm | Harmonic Centrality (make sure to EXCLUDE depart / arrive in the model)

# %%
# Applying Harmonic Centrality
pd.set_option('display.max_rows', None)


query = """

CALL gds.alpha.closeness.harmonic.stream('ds_graph', {})
YIELD nodeId, centrality
RETURN gds.util.asNode(nodeId).name AS name, centrality as closeness
ORDER BY centrality DESC

"""

my_neo4j_run_query_pandas(query)
# Out:
#                             name  closeness
# 0             green West Oakland   0.226464
# 1              blue West Oakland   0.226162
# 2            yellow West Oakland   0.225898
# 3               red West Oakland   0.225645
# 4              green Embarcadero   0.219591
# 5               blue Embarcadero   0.219339
# 6             yellow Embarcadero   0.219332
# 7                red Embarcadero   0.219117
# 8             green Lake Merritt   0.215391
# 9              blue Lake Merritt   0.215022
# 10           orange Lake Merritt   0.214990
# 11       green Montgomery Street   0.214519
# 12      yellow Montgomery Street   0.214485
# 13        blue Montgomery Street   0.214305
# 14         red Montgomery Street   0.214301
# 15            orange 12th Street   0.214112
# 16            yellow 12th Street   0.213847
# 17               red 12th Street   0.213544
# 18          yellow Powell Street   0.210260
# 19             red Powell Street   0.210100
# 20           green Powell Street   0.210093
# 21            blue Powell Street   0.209909
# 22           yellow Civic Center   0.206134
# 23              red Civic Center   0.205994
# 24            green Civic Center   0.205755
# 25             blue Civic Center   0.205594
# 26               green Fruitvale   0.204916
# 27              orange Fruitvale   0.204571
# 28                blue Fruitvale   0.204457
# 29                green Coliseum   0.201907
# 30    yellow 16th Street Mission   0.201758
# 31       red 16th Street Mission   0.201634
# 32               orange Coliseum   0.201607
# 33                 blue Coliseum   0.201317
# 34     green 16th Street Mission   0.201113
# 35      blue 16th Street Mission   0.200973
# 36            yellow 19th Street   0.200496
# 37            orange 19th Street   0.200488
# 38               red 19th Street   0.200127
# 39    yellow 24th Street Mission   0.196804
# 40       red 24th Street Mission   0.196693
# 41     green 24th Street Mission   0.195777
# 42      blue 24th Street Mission   0.195653
# 43              yellow MacArthur   0.191069
# 44              yellow Glen Park   0.190854
# 45              orange MacArthur   0.190853
# 46                 red Glen Park   0.190755
# 47                 red MacArthur   0.190609
# 48               green Glen Park   0.189183
# 49                blue Glen Park   0.189072
# 50             green San Leandro   0.188774
# 51            orange San Leandro   0.188510
# 52              blue San Leandro   0.187988
# 53                 gray Coliseum   0.186731
# 54            yellow Balboa Park   0.183201
# 55               red Balboa Park   0.183112
# 56             green Balboa Park   0.180190
# 57              blue Balboa Park   0.180091
# 58                green Bay Fair   0.180031
# 59               orange Bay Fair   0.179797
# 60                 blue Bay Fair   0.178925
# 61              yellow Daly City   0.172234
# 62                 red Daly City   0.172153
# 63                  orange Ashby   0.171261
# 64                     red Ashby   0.171089
# 65               green Daly City   0.164990
# 66                blue Daly City   0.164901
# 67                 green Hayward   0.163091
# 68                orange Hayward   0.162882
# 69              yellow Rockridge   0.161604
# 70      orange Downtown Berkeley   0.158321
# 71         red Downtown Berkeley   0.158195
# 72           green South Hayward   0.152366
# 73          orange South Hayward   0.152178
# 74                  yellow Colma   0.151863
# 75                     red Colma   0.151789
# 76            blue Castro Valley   0.148327
# 77         orange North Berkeley   0.147658
# 78            red North Berkeley   0.147564
# 79                      gray OAK   0.146679
# 80                 yellow Orinda   0.144883
# 81              green Union City   0.143752
# 82             orange Union City   0.143583
# 83    yellow South San Francisco   0.139478
# 84       red South San Francisco   0.139410
# 85       orange El Cerrito Plaza   0.137538
# 86          red El Cerrito Plaza   0.137467
# 87                 green Fremont   0.135841
# 88                orange Fremont   0.135688
# 89              yellow Lafayette   0.133103
# 90              blue West Dublin   0.128837
# 91              yellow San Bruno   0.128578
# 92                 red San Bruno   0.128516
# 93            green Warm Springs   0.127666
# 94           orange Warm Springs   0.127526
# 95   orange El Cerrito del Norte   0.126325
# 96      red El Cerrito del Norte   0.126270
# 97           yellow Walnut Creek   0.123940
# 98                green Milpitas   0.117908
# 99               orange Milpitas   0.117779
# 100         yellow Pleasant Hill   0.116320
# 101                   yellow SFO   0.111782
# 102                 red Millbrae   0.111725
# 103              orange Richmond   0.109995
# 104                 red Richmond   0.109951
# 105                  blue Dublin   0.109801
# 106               yellow Concord   0.109608
# 107                      red SFO   0.104351
# 108         yellow North Concord   0.103325
# 109              green Berryessa   0.102708
# 110             orange Berryessa   0.102590
# 111             yellow Pittsburg   0.096959
# 112      yellow Pittsburg Center   0.089628
# 113               yellow Antioch   0.078275

# %% [markdown]
# #### Algorithm | Louvain Modularity - Groupings (make sure to EXCLUDE depart / arrive in the model)

# %%
query = "CALL gds.graph.drop('ds_graph', false)"
session.run(query)

query = """

CALL gds.graph.project('ds_graph', 'Station', 'LINK', 
                      {relationshipProperties: 'track_miles'})
"""

session.run(query)

# %%
query = """

CALL gds.louvain.stream('ds_graph', {includeIntermediateCommunities: true})
YIELD nodeId, communityId, intermediateCommunityIds
RETURN gds.util.asNode(nodeId).name AS name, communityId as community, intermediateCommunityIds as intermediate_community
ORDER BY community, name ASC

"""

station_groupings_df = my_neo4j_run_query_pandas(query)

# %%
station_groupings_df['community'].value_counts()
# Out:
# 103    20
# 19     16
# 78     16
# 96     14
# 107    13
# 97     10
# 90      9
# 29      8
# 33      8
# Name: community, dtype: int64

# %%
station_groupings_df['Station'] = station_groupings_df['name'].apply(lambda x: ' '.join(x.split(' ')[1:]))
station_groupings_df
# Out:
#                             name  community intermediate_community  \
# 0       blue 16th Street Mission         19            [2, 19, 19]
# 1       blue 24th Street Mission         19            [2, 19, 19]
# 2              blue Civic Center         19           [19, 19, 19]
# 3                 blue Glen Park         19            [2, 19, 19]
# 4      green 16th Street Mission         19            [2, 19, 19]
# 5      green 24th Street Mission         19            [2, 19, 19]
# 6             green Civic Center         19           [19, 19, 19]
# 7                green Glen Park         19            [2, 19, 19]
# 8        red 16th Street Mission         19            [2, 19, 19]
# 9        red 24th Street Mission         19            [2, 19, 19]
# 10              red Civic Center         19           [19, 19, 19]
# 11                 red Glen Park         19            [2, 19, 19]
# 12    yellow 16th Street Mission         19            [2, 19, 19]
# 13    yellow 24th Street Mission         19            [2, 19, 19]
# 14           yellow Civic Center         19           [19, 19, 19]
# 15              yellow Glen Park         19            [2, 19, 19]
# 16              blue Balboa Park         29           [29, 29, 29]
# 17                blue Daly City         29           [29, 29, 29]
# 18             green Balboa Park         29           [29, 29, 29]
# 19               green Daly City         29           [29, 29, 29]
# 20               red Balboa Park         29           [29, 29, 29]
# 21                 red Daly City         29           [29, 29, 29]
# 22            yellow Balboa Park         29           [29, 29, 29]
# 23              yellow Daly City         29           [29, 29, 29]
# 24       orange El Cerrito Plaza         33           [33, 33, 33]
# 25   orange El Cerrito del Norte         33           [81, 33, 33]
# 26         orange North Berkeley         33           [33, 33, 33]
# 27               orange Richmond         33           [81, 33, 33]
# 28          red El Cerrito Plaza         33           [33, 33, 33]
# 29      red El Cerrito del Norte         33           [81, 33, 33]
# 30            red North Berkeley         33           [33, 33, 33]
# 31                  red Richmond         33           [81, 33, 33]
# 32              blue Embarcadero         78           [41, 78, 78]
# 33        blue Montgomery Street         78           [41, 78, 78]
# 34            blue Powell Street         78           [78, 78, 78]
# 35             blue West Oakland         78          [103, 78, 78]
# 36             green Embarcadero         78           [41, 78, 78]
# 37       green Montgomery Street         78           [41, 78, 78]
# 38           green Powell Street         78           [78, 78, 78]
# 39            green West Oakland         78          [103, 78, 78]
# 40               red Embarcadero         78           [41, 78, 78]
# 41         red Montgomery Street         78           [41, 78, 78]
# 42             red Powell Street         78           [78, 78, 78]
# 43              red West Oakland         78          [103, 78, 78]
# 44            yellow Embarcadero         78           [41, 78, 78]
# 45      yellow Montgomery Street         78           [41, 78, 78]
# 46          yellow Powell Street         78           [78, 78, 78]
# 47           yellow West Oakland         78          [103, 78, 78]
# 48                     red Colma         90           [27, 90, 90]
# 49                  red Millbrae         90           [89, 90, 90]
# 50                       red SFO         90           [89, 90, 90]
# 51                 red San Bruno         90           [93, 90, 90]
# 52       red South San Francisco         90           [93, 90, 90]
# 53                  yellow Colma         90           [27, 90, 90]
# 54                    yellow SFO         90           [89, 90, 90]
# 55              yellow San Bruno         90           [90, 90, 90]
# 56    yellow South San Francisco         90           [90, 90, 90]
# 57               green Berryessa         96           [16, 99, 96]
# 58                 green Fremont         96           [45, 99, 96]
# 59                 green Hayward         96           [54, 96, 96]
# 60                green Milpitas         96           [16, 99, 96]
# 61           green South Hayward         96           [54, 96, 96]
# 62              green Union City         96           [96, 96, 96]
# 63            green Warm Springs         96           [99, 99, 96]
# 64              orange Berryessa         96           [16, 99, 96]
# 65                orange Fremont         96           [45, 99, 96]
# 66                orange Hayward         96           [54, 96, 96]
# 67               orange Milpitas         96           [16, 99, 96]
# 68          orange South Hayward         96           [54, 96, 96]
# 69             orange Union City         96           [96, 96, 96]
# 70           orange Warm Springs         96           [99, 99, 96]
# 71                yellow Antioch         97           [75, 71, 97]
# 72                yellow Concord         97           [71, 71, 97]
# 73              yellow Lafayette         97           [73, 97, 97]
# 74          yellow North Concord         97           [71, 71, 97]
# 75                 yellow Orinda         97           [73, 97, 97]
# 76              yellow Pittsburg         97           [75, 71, 97]
# 77       yellow Pittsburg Center         97           [75, 71, 97]
# 78          yellow Pleasant Hill         97           [97, 97, 97]
# 79              yellow Rockridge         97           [73, 97, 97]
# 80           yellow Walnut Creek         97           [97, 97, 97]
# 81                 blue Bay Fair        103          [17, 88, 103]
# 82            blue Castro Valley        103         [100, 88, 103]
# 83                 blue Coliseum        103         [23, 103, 103]
# 84                   blue Dublin        103         [100, 88, 103]
# 85                blue Fruitvale        103         [46, 103, 103]
# 86             blue Lake Merritt        103         [46, 103, 103]
# 87              blue San Leandro        103          [88, 88, 103]
# 88              blue West Dublin        103         [100, 88, 103]
# 89                 gray Coliseum        103         [23, 103, 103]
# 90                      gray OAK        103         [23, 103, 103]
# 91                green Bay Fair        103          [17, 88, 103]
# 92                green Coliseum        103         [23, 103, 103]
# 93               green Fruitvale        103         [46, 103, 103]
# 94            green Lake Merritt        103         [46, 103, 103]
# 95             green San Leandro        103          [88, 88, 103]
# 96               orange Bay Fair        103          [17, 88, 103]
# 97               orange Coliseum        103         [23, 103, 103]
# 98              orange Fruitvale        103         [46, 103, 103]
# 99           orange Lake Merritt        103         [46, 103, 103]
# 100           orange San Leandro        103          [88, 88, 103]
# 101           orange 12th Street        107        [107, 107, 107]
# 102           orange 19th Street        107        [113, 107, 107]
# 103                 orange Ashby        107          [7, 107, 107]
# 104     orange Downtown Berkeley        107          [7, 107, 107]
# 105             orange MacArthur        107          [7, 107, 107]
# 106              red 12th Street        107        [107, 107, 107]
# 107              red 19th Street        107        [113, 107, 107]
# 108                    red Ashby        107          [7, 107, 107]
# 109        red Downtown Berkeley        107          [7, 107, 107]
# 110                red MacArthur        107          [7, 107, 107]
# 111           yellow 12th Street        107        [107, 107, 107]
# 112           yellow 19th Street        107        [113, 107, 107]
# 113             yellow MacArthur        107          [7, 107, 107]
#
#                   Station
# 0     16th Street Mission
# 1     24th Street Mission
# 2            Civic Center
# 3               Glen Park
# 4     16th Street Mission
# 5     24th Street Mission
# 6            Civic Center
# 7               Glen Park
# 8     16th Street Mission
# 9     24th Street Mission
# 10           Civic Center
# 11              Glen Park
# 12    16th Street Mission
# 13    24th Street Mission
# 14           Civic Center
# 15              Glen Park
# 16            Balboa Park
# 17              Daly City
# 18            Balboa Park
# 19              Daly City
# 20            Balboa Park
# 21              Daly City
# 22            Balboa Park
# 23              Daly City
# 24       El Cerrito Plaza
# 25   El Cerrito del Norte
# 26         North Berkeley
# 27               Richmond
# 28       El Cerrito Plaza
# 29   El Cerrito del Norte
# 30         North Berkeley
# 31               Richmond
# 32            Embarcadero
# 33      Montgomery Street
# 34          Powell Street
# 35           West Oakland
# 36            Embarcadero
# 37      Montgomery Street
# 38          Powell Street
# 39           West Oakland
# 40            Embarcadero
# 41      Montgomery Street
# 42          Powell Street
# 43           West Oakland
# 44            Embarcadero
# 45      Montgomery Street
# 46          Powell Street
# 47           West Oakland
# 48                  Colma
# 49               Millbrae
# 50                    SFO
# 51              San Bruno
# 52    South San Francisco
# 53                  Colma
# 54                    SFO
# 55              San Bruno
# 56    South San Francisco
# 57              Berryessa
# 58                Fremont
# 59                Hayward
# 60               Milpitas
# 61          South Hayward
# 62             Union City
# 63           Warm Springs
# 64              Berryessa
# 65                Fremont
# 66                Hayward
# 67               Milpitas
# 68          South Hayward
# 69             Union City
# 70           Warm Springs
# 71                Antioch
# 72                Concord
# 73              Lafayette
# 74          North Concord
# 75                 Orinda
# 76              Pittsburg
# 77       Pittsburg Center
# 78          Pleasant Hill
# 79              Rockridge
# 80           Walnut Creek
# 81               Bay Fair
# 82          Castro Valley
# 83               Coliseum
# 84                 Dublin
# 85              Fruitvale
# 86           Lake Merritt
# 87            San Leandro
# 88            West Dublin
# 89               Coliseum
# 90                    OAK
# 91               Bay Fair
# 92               Coliseum
# 93              Fruitvale
# 94           Lake Merritt
# 95            San Leandro
# 96               Bay Fair
# 97               Coliseum
# 98              Fruitvale
# 99           Lake Merritt
# 100           San Leandro
# 101           12th Street
# 102           19th Street
# 103                 Ashby
# 104     Downtown Berkeley
# 105             MacArthur
# 106           12th Street
# 107           19th Street
# 108                 Ashby
# 109     Downtown Berkeley
# 110             MacArthur
# 111           12th Street
# 112           19th Street
# 113             MacArthur

# %% [markdown]
# #### Algorithm | Geodesic Fencing - within 2 miles (make sure to EXCLUDE depart / arrive in the model)

# %%
# Zip codes with population within 2 miles of the coliseum station
my_station_get_zips('Coliseum',2)
# Out:
# -------------------------------------------------------------------------------
#   Zip Codes within 2 mile(s) of Coliseum BART Station
# -------------------------------------------------------------------------------
#
#      zip: 94601   population:      52,299
#      zip: 94603   population:      34,593
#      zip: 94613   population:         861
#      zip: 94621   population:      35,287
#
# -------------------------------------------------------------------------------
#   Total Population:     123,040
# -------------------------------------------------------------------------------

# %%
# ALl zip codes and population with 1,2,3,4,5 miles of downtown berkeley station
for x in range(1,6):
    my_station_get_zips('Downtown Berkeley', x)
# Out:
# -------------------------------------------------------------------------------
#   Zip Codes within 1 mile(s) of Downtown Berkeley BART Station
# -------------------------------------------------------------------------------
#
#      zip: 94702   population:      17,092
#      zip: 94703   population:      21,937
#      zip: 94704   population:      29,190
#      zip: 94709   population:      11,740
#      zip: 94720   population:       2,971
#
# -------------------------------------------------------------------------------
#   Total Population:      82,930
# -------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------
#   Zip Codes within 2 mile(s) of Downtown Berkeley BART Station
# -------------------------------------------------------------------------------
#
#      zip: 94618   population:      17,041
#      zip: 94702   population:      17,092
#      zip: 94703   population:      21,937
#      zip: 94704   population:      29,190
#      zip: 94705   population:      13,365
#      zip: 94706   population:      21,040
#      zip: 94707   population:      11,916
#      zip: 94709   population:      11,740
#      zip: 94710   population:       7,461
#      zip: 94720   population:       2,971
#
# -------------------------------------------------------------------------------
#   Total Population:     153,753
# -------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------
#   Zip Codes within 3 mile(s) of Downtown Berkeley BART Station
# -------------------------------------------------------------------------------
#
#      zip: 94608   population:      30,289
#      zip: 94609   population:      22,811
#      zip: 94618   population:      17,041
#      zip: 94702   population:      17,092
#      zip: 94703   population:      21,937
#      zip: 94704   population:      29,190
#      zip: 94705   population:      13,365
#      zip: 94706   population:      21,040
#      zip: 94707   population:      11,916
#      zip: 94708   population:      11,455
#      zip: 94709   population:      11,740
#      zip: 94710   population:       7,461
#      zip: 94720   population:       2,971
#
# -------------------------------------------------------------------------------
#   Total Population:     218,308
# -------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------
#   Zip Codes within 4 mile(s) of Downtown Berkeley BART Station
# -------------------------------------------------------------------------------
#
#      zip: 94530   population:      25,754
#      zip: 94608   population:      30,289
#      zip: 94609   population:      22,811
#      zip: 94611   population:      39,384
#      zip: 94618   population:      17,041
#      zip: 94702   population:      17,092
#      zip: 94703   population:      21,937
#      zip: 94704   population:      29,190
#      zip: 94705   population:      13,365
#      zip: 94706   population:      21,040
#      zip: 94707   population:      11,916
#      zip: 94708   population:      11,455
#      zip: 94709   population:      11,740
#      zip: 94710   population:       7,461
#      zip: 94720   population:       2,971
#
# -------------------------------------------------------------------------------
#   Total Population:     283,446
# -------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------
#   Zip Codes within 5 mile(s) of Downtown Berkeley BART Station
# -------------------------------------------------------------------------------
#
#      zip: 94530   population:      25,754
#      zip: 94563   population:      19,341
#      zip: 94602   population:      29,933
#      zip: 94607   population:      26,254
#      zip: 94608   population:      30,289
#      zip: 94609   population:      22,811
#      zip: 94610   population:      31,496
#      zip: 94611   population:      39,384
#      zip: 94612   population:      16,062
#      zip: 94618   population:      17,041
#      zip: 94702   population:      17,092
#      zip: 94703   population:      21,937
#      zip: 94704   population:      29,190
#      zip: 94705   population:      13,365
#      zip: 94706   population:      21,040
#      zip: 94707   population:      11,916
#      zip: 94708   population:      11,455
#      zip: 94709   population:      11,740
#      zip: 94710   population:       7,461
#      zip: 94720   population:       2,971
#      zip: 94804   population:      41,510
#
# -------------------------------------------------------------------------------
#   Total Population:     448,042
# -------------------------------------------------------------------------------

# %%
all_stations_population_dictionary = {}

for station in stations:
    result = my_station_get_population(station, 2)
    all_stations_population_dictionary.update(result)
    
population_df = pd.DataFrame.from_dict(all_stations_population_dictionary, orient='index').reset_index()
population_df.columns = ['Station', 'Population']

# %%
joined_df = pd.merge(population_df,station_groupings_df, on='Station',how='inner')
joined_df.sort_values('Population',ascending = False)
# Out:
#                   Station  Population                         name  community  \
# 30           Civic Center      347795          yellow Civic Center         19
# 29           Civic Center      347795             red Civic Center         19
# 28           Civic Center      347795           green Civic Center         19
# 27           Civic Center      347795            blue Civic Center         19
# 3     16th Street Mission      339093     blue 16th Street Mission         19
# 4     16th Street Mission      339093    green 16th Street Mission         19
# 5     16th Street Mission      339093      red 16th Street Mission         19
# 6     16th Street Mission      339093   yellow 16th Street Mission         19
# 10    24th Street Mission      315201     blue 24th Street Mission         19
# 11    24th Street Mission      315201    green 24th Street Mission         19
# 12    24th Street Mission      315201      red 24th Street Mission         19
# 13    24th Street Mission      315201   yellow 24th Street Mission         19
# 87          Powell Street      303556          green Powell Street         78
# 89          Powell Street      303556         yellow Powell Street         78
# 86          Powell Street      303556           blue Powell Street         78
# 88          Powell Street      303556            red Powell Street         78
# 61              Glen Park      287877             yellow Glen Park         19
# 60              Glen Park      287877                red Glen Park         19
# 59              Glen Park      287877              green Glen Park         19
# 58              Glen Park      287877               blue Glen Park         19
# 74      Montgomery Street      268802       blue Montgomery Street         78
# 75      Montgomery Street      268802      green Montgomery Street         78
# 76      Montgomery Street      268802        red Montgomery Street         78
# 77      Montgomery Street      268802     yellow Montgomery Street         78
# 17            Balboa Park      253123             blue Balboa Park         29
# 18            Balboa Park      253123            green Balboa Park         29
# 19            Balboa Park      253123              red Balboa Park         29
# 20            Balboa Park      253123           yellow Balboa Park         29
# 38              Daly City      231056               blue Daly City         29
# 41              Daly City      231056             yellow Daly City         29
# 39              Daly City      231056              green Daly City         29
# 40              Daly City      231056                red Daly City         29
# 52            Embarcadero      210921           yellow Embarcadero         78
# 51            Embarcadero      210921              red Embarcadero         78
# 50            Embarcadero      210921            green Embarcadero         78
# 49            Embarcadero      210921             blue Embarcadero         78
# 24              Berryessa      197640              green Berryessa         96
# 25              Berryessa      197640             orange Berryessa         96
# 103   South San Francisco      186691   yellow South San Francisco         90
# 102   South San Francisco      186691      red South San Francisco         90
# 66           Lake Merritt      175958           green Lake Merritt        103
# 1             12th Street      175958              red 12th Street        107
# 67           Lake Merritt      175958          orange Lake Merritt        103
# 0             12th Street      175958           orange 12th Street        107
# 65           Lake Merritt      175958            blue Lake Merritt        103
# 2             12th Street      175958           yellow 12th Street        107
# 15                  Ashby      173897                 orange Ashby        107
# 16                  Ashby      173897                    red Ashby        107
# 7             19th Street      165215           orange 19th Street        107
# 9             19th Street      165215           yellow 19th Street        107
# 8             19th Street      165215              red 19th Street        107
# 42      Downtown Berkeley      153753     orange Downtown Berkeley        107
# 43      Downtown Berkeley      153753        red Downtown Berkeley        107
# 92              Rockridge      151725             yellow Rockridge         97
# 104            Union City      148456             green Union City         96
# 105            Union City      148456            orange Union City         96
# 70              MacArthur      143953             yellow MacArthur        107
# 69              MacArthur      143953                red MacArthur        107
# 68              MacArthur      143953             orange MacArthur        107
# 78         North Berkeley      134802        orange North Berkeley         33
# 79         North Berkeley      134802           red North Berkeley         33
# 95            San Leandro      123740             blue San Leandro        103
# 96            San Leandro      123740            green San Leandro        103
# 97            San Leandro      123740           orange San Leandro        103
# 32               Coliseum      123040                gray Coliseum        103
# 34               Coliseum      123040              orange Coliseum        103
# 33               Coliseum      123040               green Coliseum        103
# 31               Coliseum      123040                blue Coliseum        103
# 108          Warm Springs      120913          orange Warm Springs         96
# 107          Warm Springs      120913           green Warm Springs         96
# 35                  Colma      114402                    red Colma         90
# 36                  Colma      114402                 yellow Colma         90
# 94              San Bruno      110856             yellow San Bruno         90
# 93              San Bruno      110856                red San Bruno         90
# 26          Castro Valley      110328           blue Castro Valley        103
# 84       Pittsburg Center       96081      yellow Pittsburg Center         97
# 100         South Hayward       93452          green South Hayward         96
# 101         South Hayward       93452         orange South Hayward         96
# 23               Bay Fair       93041              orange Bay Fair        103
# 22               Bay Fair       93041               green Bay Fair        103
# 21               Bay Fair       93041                blue Bay Fair        103
# 57              Fruitvale       90602             orange Fruitvale        103
# 56              Fruitvale       90602              green Fruitvale        103
# 55              Fruitvale       90602               blue Fruitvale        103
# 37                Concord       87117               yellow Concord         97
# 85          Pleasant Hill       86258         yellow Pleasant Hill         97
# 90               Richmond       85676              orange Richmond         33
# 91               Richmond       85676                 red Richmond         33
# 81                    OAK       84499                     gray OAK        103
# 45   El Cerrito del Norte       81472  orange El Cerrito del Norte         33
# 46   El Cerrito del Norte       81472     red El Cerrito del Norte         33
# 53                Fremont       73855                green Fremont         96
# 54                Fremont       73855               orange Fremont         96
# 47       El Cerrito Plaza       70450      orange El Cerrito Plaza         33
# 48       El Cerrito Plaza       70450         red El Cerrito Plaza         33
# 14                Antioch       66933               yellow Antioch         97
# 62                Hayward       66056                green Hayward         96
# 63                Hayward       66056               orange Hayward         96
# 80          North Concord       58689         yellow North Concord         97
# 109           West Dublin       54420             blue West Dublin        103
# 44                 Dublin       54420                  blue Dublin        103
# 106          Walnut Creek       43556          yellow Walnut Creek         97
# 111          West Oakland       42316           green West Oakland         78
# 110          West Oakland       42316            blue West Oakland         78
# 112          West Oakland       42316             red West Oakland         78
# 113          West Oakland       42316          yellow West Oakland         78
# 72               Milpitas       31170               green Milpitas         96
# 73               Milpitas       31170              orange Milpitas         96
# 64              Lafayette       29639             yellow Lafayette         97
# 98                    SFO       22845                      red SFO         90
# 99                    SFO       22845                   yellow SFO         90
# 71               Millbrae       22845                 red Millbrae         90
# 82                 Orinda       19341                yellow Orinda         97
# 83              Pittsburg           0             yellow Pittsburg         97
#
#     intermediate_community
# 30            [19, 19, 19]
# 29            [19, 19, 19]
# 28            [19, 19, 19]
# 27            [19, 19, 19]
# 3              [2, 19, 19]
# 4              [2, 19, 19]
# 5              [2, 19, 19]
# 6              [2, 19, 19]
# 10             [2, 19, 19]
# 11             [2, 19, 19]
# 12             [2, 19, 19]
# 13             [2, 19, 19]
# 87            [78, 78, 78]
# 89            [78, 78, 78]
# 86            [78, 78, 78]
# 88            [78, 78, 78]
# 61             [2, 19, 19]
# 60             [2, 19, 19]
# 59             [2, 19, 19]
# 58             [2, 19, 19]
# 74            [41, 78, 78]
# 75            [41, 78, 78]
# 76            [41, 78, 78]
# 77            [41, 78, 78]
# 17            [29, 29, 29]
# 18            [29, 29, 29]
# 19            [29, 29, 29]
# 20            [29, 29, 29]
# 38            [29, 29, 29]
# 41            [29, 29, 29]
# 39            [29, 29, 29]
# 40            [29, 29, 29]
# 52            [41, 78, 78]
# 51            [41, 78, 78]
# 50            [41, 78, 78]
# 49            [41, 78, 78]
# 24            [16, 99, 96]
# 25            [16, 99, 96]
# 103           [90, 90, 90]
# 102           [93, 90, 90]
# 66          [46, 103, 103]
# 1          [107, 107, 107]
# 67          [46, 103, 103]
# 0          [107, 107, 107]
# 65          [46, 103, 103]
# 2          [107, 107, 107]
# 15           [7, 107, 107]
# 16           [7, 107, 107]
# 7          [113, 107, 107]
# 9          [113, 107, 107]
# 8          [113, 107, 107]
# 42           [7, 107, 107]
# 43           [7, 107, 107]
# 92            [73, 97, 97]
# 104           [96, 96, 96]
# 105           [96, 96, 96]
# 70           [7, 107, 107]
# 69           [7, 107, 107]
# 68           [7, 107, 107]
# 78            [33, 33, 33]
# 79            [33, 33, 33]
# 95           [88, 88, 103]
# 96           [88, 88, 103]
# 97           [88, 88, 103]
# 32          [23, 103, 103]
# 34          [23, 103, 103]
# 33          [23, 103, 103]
# 31          [23, 103, 103]
# 108           [99, 99, 96]
# 107           [99, 99, 96]
# 35            [27, 90, 90]
# 36            [27, 90, 90]
# 94            [90, 90, 90]
# 93            [93, 90, 90]
# 26          [100, 88, 103]
# 84            [75, 71, 97]
# 100           [54, 96, 96]
# 101           [54, 96, 96]
# 23           [17, 88, 103]
# 22           [17, 88, 103]
# 21           [17, 88, 103]
# 57          [46, 103, 103]
# 56          [46, 103, 103]
# 55          [46, 103, 103]
# 37            [71, 71, 97]
# 85            [97, 97, 97]
# 90            [81, 33, 33]
# 91            [81, 33, 33]
# 81          [23, 103, 103]
# 45            [81, 33, 33]
# 46            [81, 33, 33]
# 53            [45, 99, 96]
# 54            [45, 99, 96]
# 47            [33, 33, 33]
# 48            [33, 33, 33]
# 14            [75, 71, 97]
# 62            [54, 96, 96]
# 63            [54, 96, 96]
# 80            [71, 71, 97]
# 109         [100, 88, 103]
# 44          [100, 88, 103]
# 106           [97, 97, 97]
# 111          [103, 78, 78]
# 110          [103, 78, 78]
# 112          [103, 78, 78]
# 113          [103, 78, 78]
# 72            [16, 99, 96]
# 73            [16, 99, 96]
# 64            [73, 97, 97]
# 98            [89, 90, 90]
# 99            [89, 90, 90]
# 71            [89, 90, 90]
# 82            [73, 97, 97]
# 83            [75, 71, 97]

# %%
df_no_duplicates_subset = joined_df.drop_duplicates(subset='Station')
df_no_duplicates_subset = df_no_duplicates_subset.drop(columns=['intermediate_community', 'name'])

# %%
top_3_per_community = df_no_duplicates_subset.groupby('community').head(3)
top_3_per_community.sort_values(by=['community','Population'],ascending = [True, False])
# Out:
#                  Station  Population  community
# 27          Civic Center      347795         19
# 3    16th Street Mission      339093         19
# 10   24th Street Mission      315201         19
# 17           Balboa Park      253123         29
# 38             Daly City      231056         29
# 78        North Berkeley      134802         33
# 45  El Cerrito del Norte       81472         33
# 47      El Cerrito Plaza       70450         33
# 86         Powell Street      303556         78
# 74     Montgomery Street      268802         78
# 49           Embarcadero      210921         78
# 35                 Colma      114402         90
# 93             San Bruno      110856         90
# 71              Millbrae       22845         90
# 24             Berryessa      197640         96
# 53               Fremont       73855         96
# 62               Hayward       66056         96
# 37               Concord       87117         97
# 14               Antioch       66933         97
# 64             Lafayette       29639         97
# 31              Coliseum      123040        103
# 26         Castro Valley      110328        103
# 21              Bay Fair       93041        103
# 0            12th Street      175958        107
# 15                 Ashby      173897        107
# 7            19th Street      165215        107

# %%
filtered_df = top_3_per_community[top_3_per_community['community'] == 19]
filtered_df.sort_values('Population',ascending = False)
# Out:
#                 Station  Population  community
# 27         Civic Center      347795         19
# 3   16th Street Mission      339093         19
# 10  24th Street Mission      315201         19
